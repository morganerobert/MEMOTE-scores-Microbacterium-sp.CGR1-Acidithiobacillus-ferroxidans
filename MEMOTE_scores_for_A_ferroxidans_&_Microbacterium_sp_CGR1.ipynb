# %% [markdown]
# <a href="https://colab.research.google.com/github/morganerobert/MEMOTE-scores-Microbacterium-sp.CGR1-Acidithiobacillus-ferroxidans/blob/main/MEMOTE_scores_for_A_ferroxidans_%26_Microbacterium_sp_CGR1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MEMOTE Score : Acidithiobacillus ferroxidans

# %%
# !pip install memote
# !pip install cobra

# %%
# Download the GitHub repository
# !git clone https://github.com/morganerobert/MEMOTE-scores-Microbacterium-sp.CGR1-Acidithiobacillus-ferroxidans.git

# Move into the repository folder
# %cd MEMOTE-scores-Microbacterium-sp.CGR1-Acidithiobacillus-ferroxidans
# Out:
# fatal: destination path 'MEMOTE-scores-Microbacterium-sp.CGR1-Acidithiobacillus-ferroxidans' already exists and is not an empty directory.
# /content/MEMOTE-scores-Microbacterium-sp.CGR1-Acidithiobacillus-ferroxidans

# %%
from cobra.io import read_sbml_model

model = read_sbml_model("models/A_ferroxidans_model.xml")
# Out:
# WARNING:cobra.io.sbml:Model does not contain SBML fbc package information.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# WARNING:cobra.io.sbml:SBML package 'layout' not supported by cobrapy, information is not parsed
# WARNING:cobra.io.sbml:SBML package 'render' not supported by cobrapy, information is not parsed
# WARNING:cobra.io.sbml:Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_tsul_p "Thiosulfate">
# WARNING:cobra.io.sbml:Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_tsul_p "Thiosulfate">
# WARNING:cobra.io.sbml:Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_s_p "Sulfur">
# WARNING:cobra.io.sbml:Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_s_p "Sulfur">
# WARNING:cobra.io.sbml:Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_h_p "h">
# ...

# %%
# !memote report snapshot \
    models/A_ferroxidans_model.xml \
    --filename A_ferroxidans_memote.html
# Out:
# /usr/local/lib/python3.12/dist-packages/pandera/_pandas_deprecated.py:155: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)
# ...
# error: '' is not a valid SBML 'SId'.
# ...

# %%
from google.colab import files
files.download("A_ferroxidans_memote.html")

# %% [markdown]
# #MEMOTE Score : Microbacterium sp. CGR1

# %%
# !memote report snapshot \
    models/MicrobacteriumCGR1_model.xml \
    --filename Microbacterium_spCGR1_memote.html
# Out:
# /usr/local/lib/python3.12/dist-packages/pandera/_pandas_deprecated.py:155: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...

# %%
files.download("Microbacterium_spCGR1_memote.html")
